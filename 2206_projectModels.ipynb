# %% [markdown]
# ## 2006 Capstone Project Model python file

# %% [markdown]
# ## Data cleaning Part 1

# %%
#Load Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#read in the csv
data = pd.read_csv("project_data.csv")
data.head(10)
# Out:
#    CountryName CountryCode                                         SeriesName  \
# 0  Afghanistan         AFG                             Broad money (% of GDP)
# 1  Afghanistan         AFG                CO2 emissions (kg per PPP $ of GDP)
# 2  Afghanistan         AFG           Exports of goods and services (% of GDP)
# 3  Afghanistan         AFG                              GDP growth (annual %)
# 4  Afghanistan         AFG  Foreign direct investment, net inflows (% of GDP)
# 5  Afghanistan         AFG  Foreign direct investment, net outflows (% of ...
# 6  Afghanistan         AFG                   GDP per capita growth (annual %)
# 7  Afghanistan         AFG           Imports of goods and services (% of GDP)
# 8  Afghanistan         AFG                       Merchandise trade (% of GDP)
# 9  Afghanistan         AFG                 Inflation, GDP deflator (annual %)
#
#              SeriesCode 1960 [YR1960] 1961 [YR1961] 1962 [YR1962]  \
# ...

# %%
data.shape
# Out:
# (3689, 65)

# %%
data.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3689 entries, 0 to 3688
# Data columns (total 65 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   CountryName    3689 non-null   object
#  1   CountryCode    3689 non-null   object
#  2   SeriesName     3689 non-null   object
#  3   SeriesCode     3689 non-null   object
#  4   1960 [YR1960]  3689 non-null   object
#  5   1961 [YR1961]  3689 non-null   object
#  6   1962 [YR1962]  3689 non-null   object
#  7   1963 [YR1963]  3689 non-null   object
#  8   1964 [YR1964]  3689 non-null   object
#  9   1965 [YR1965]  3689 non-null   object
#  10  1966 [YR1966]  3689 non-null   object
#  11  1967 [YR1967]  3689 non-null   object
#  12  1968 [YR1968]  3689 non-null   object
#  13  1969 [YR1969]  3689 non-null   object
#  14  1970 [YR1970]  3689 non-null   object
#  15  1971 [YR1971]  3689 non-null   object
#  16  1972 [YR1972]  3689 non-null   object
# ...

# %%
data.describe()
# Out:
#        Broad money (% of GDP)  CO2 emissions (kg per PPP $ of GDP)  \
# count             3958.000000                          4253.000000
# mean                55.723593                             0.304863
# std                 43.346027                             0.261622
# min                  2.857408                             0.000000
# 25%                 26.485238                             0.149229
# 50%                 45.609950                             0.238932
# 75%                 71.265322                             0.356092
# max                452.548038                             2.568664
#
#        Exports of goods and services (% of GDP)  GDP growth (annual %)  \
# count                               4483.000000            4917.000000
# mean                                  41.295108               3.351913
# std                                   31.397671               5.557260
# min                                    0.005377             -62.075920
# ...

# %%
dataset = data.replace('..', np.nan)

# %%
#counting missing value percentage for each column
percent_missing = dataset.isna().sum()/ len(data) *100
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df.sort_values(by=['percent_missing'], ascending=False)
missing_value_df.head(20)
# Out:
#                percent_missing
# CountryName           0.000000
# CountryCode           0.000000
# SeriesName            0.000000
# SeriesCode            0.000000
# 1960 [YR1960]        66.386049
# 1961 [YR1961]        60.533173
# 1962 [YR1962]        60.012026
# 1963 [YR1963]        59.891762
# 1964 [YR1964]        59.731409
# 1965 [YR1965]        58.909601
# 1966 [YR1966]        58.228102
# 1967 [YR1967]        57.747043
# 1968 [YR1968]        57.466426
# 1969 [YR1969]        57.225897
# 1970 [YR1970]        53.577871
# 1971 [YR1971]        52.555622
# 1972 [YR1972]        51.453197
# 1973 [YR1973]        51.272800
# 1974 [YR1974]        50.571257
# 1975 [YR1975]        49.188214

# %% [markdown]
#  dropping all years pre 1990 because they are missing too much data

# %%
dataset2 = dataset.drop(["1960 [YR1960]","1961 [YR1961]","1962 [YR1962]","1963 [YR1963]","1964 [YR1964]","1965 [YR1965]","1966 [YR1966]","1967 [YR1967]","1968 [YR1968]","1969 [YR1969]", "1970 [YR1970]","1971 [YR1971]","1972 [YR1972]","1973 [YR1973]","1974 [YR1974]","1975 [YR1975]","1976 [YR1976]","1977 [YR1977]","1978 [YR1978]","1979 [YR1979]","1980 [YR1980]","1981 [YR1981]","1982 [YR1982]","1983 [YR1983]","1984 [YR1984]","1985 [YR1985]","1986 [YR1986]","1987 [YR1987]","1988 [YR1988]","1989 [YR1989]", "1990 [YR1990]", "1991 [YR1991]", "1992 [YR1992]", "1993 [YR1993]", "1994 [YR1994]"], axis=1)

# %%
dataset3 = dataset2.drop(['CountryName', 'CountryCode', 'SeriesCode'],axis=1)

# %%
dataset3
# Out:
#                                              SeriesName 1995 [YR1995]  \
# 0                                Broad money (% of GDP)           NaN
# 1                   CO2 emissions (kg per PPP $ of GDP)           NaN
# 2              Exports of goods and services (% of GDP)           NaN
# 3                                 GDP growth (annual %)           NaN
# 4     Foreign direct investment, net inflows (% of GDP)           NaN
# ...                                                 ...           ...
# 3684      GDP per person employed (constant 2017 PPP $)   9147.864381
# 3685  Logistics performance index: Quality of trade ...           NaN
# 3686              Net trade in goods (BoP, current US$)           NaN
# 3687         Taxes on international trade (current LCU)           NaN
# 3688          International tourism, number of arrivals       1416000
#
#      1996 [YR1996] 1997 [YR1997] 1998 [YR1998] 1999 [YR1999] 2000 [YR2000]  \
# ...

# %%
colnames = ['Broad money (% of GDP)','CO2 emissions (kg per PPP $ of GDP)','Exports of goods and services (% of GDP)','GDP growth (annual %)','Foreign direct investment, net inflows (% of GDP)','Foreign direct investment, net outflows (% of GDP)','GDP per capita growth (annual %)','Imports of goods and services (% of GDP)','Merchandise trade (% of GDP)','Inflation, GDP deflator (annual %)','Trade (% of GDP)','Services, value added (% of GDP)','GDP per person employed (constant 2017 PPP $)','Logistics performance index: Quality of trade and transport-related infrastructure (1=low to 5=high)','Net trade in goods (BoP, current US$)','Taxes on international trade (current LCU)','International tourism, number of arrivals']

# %%
colnames
# Out:
# ['Broad money (% of GDP)',
#  'CO2 emissions (kg per PPP $ of GDP)',
#  'Exports of goods and services (% of GDP)',
#  'GDP growth (annual %)',
#  'Foreign direct investment, net inflows (% of GDP)',
#  'Foreign direct investment, net outflows (% of GDP)',
#  'GDP per capita growth (annual %)',
#  'Imports of goods and services (% of GDP)',
#  'Merchandise trade (% of GDP)',
#  'Inflation, GDP deflator (annual %)',
#  'Trade (% of GDP)',
#  'Services, value added (% of GDP)',
#  'GDP per person employed (constant 2017 PPP $)',
#  'Logistics performance index: Quality of trade and transport-related infrastructure (1=low to 5=high)',
#  'Net trade in goods (BoP, current US$)',
#  'Taxes on international trade (current LCU)',
#  'International tourism, number of arrivals']

# %%
#write to csv for further editing
#dataset3.to_csv('testData.csv', index=False)

# %% [markdown]
# ## Wrote dataset to a excel csv to further edit in Power Query

# %% [markdown]
# ## After editing the dataset with power query

# %%
#read in the csv
tData = pd.read_excel('transposedData.xlsx')
tData
# Out:
#       Broad money (% of GDP)  CO2 emissions (kg per PPP $ of GDP)  \
# 0                        NaN                                  NaN
# 1                        NaN                                  NaN
# 2                        NaN                                  NaN
# 3                        NaN                                  NaN
# 4                        NaN                                  NaN
# ...                      ...                                  ...
# 4984               34.968710                             0.230335
# 4985                     NaN                                  NaN
# 4986                     NaN                                  NaN
# 4987                     NaN                             0.481543
# 4988               22.451986                             0.342305
#
#       Exports of goods and services (% of GDP)  GDP growth (annual %)  \
# 0                                          NaN                    NaN
# ...

# %%
tData.shape
# Out:
# (4989, 17)

# %%
#Importing package
import pandas_profiling as pp
from IPython.display import IFrame
 

# Profile Report
dataReport = pp.ProfileReport(tData)
dataReport.to_file('dataReport.html')
display(IFrame('dataReport.html', width=900, height=350))
# Out:
#         <iframe
#             width="900"
#             height="350"
#             src="dataReport.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
#counting missing value percentage for each column
percent_missing = tData.isna().sum()/ len(tData) *100
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df = missing_value_df.sort_values(by=['percent_missing'], ascending=False)
missing_value_df
# Out:
#                                                     percent_missing
# Logistics performance index: Quality of trade a...        81.639607
# Taxes on international trade (current LCU)                45.259571
# Broad money (% of GDP)                                    20.665464
# Foreign direct investment, net outflows (% of GDP)        14.852676
# CO2 emissions (kg per PPP $ of GDP)                       14.752455
# Net trade in goods (BoP, current US$)                     13.589898
# GDP per person employed (constant 2017 PPP $)             11.385047
# International tourism, number of arrivals                 11.124474
# Imports of goods and services (% of GDP)                  10.142313
# Trade (% of GDP)                                          10.142313
# Exports of goods and services (% of GDP)                  10.142313
# Services, value added (% of GDP)                           8.558829
# Foreign direct investment, net inflows (% of GDP)          4.810583
# ...

# %% [markdown]
# dropping:
# logistics index - missing too many values
# taxes on international trade- missing too many values

# %% [markdown]
# remove all rows that have an NA for the dependent variable tourism arrivals

# %%
#dropping
nextData = tData.drop(["Logistics performance index: Quality of trade and transport-related infrastructure (1=low to 5=high)", "Taxes on international trade (current LCU)"], axis=1)
nextData
# Out:
#       Broad money (% of GDP)  CO2 emissions (kg per PPP $ of GDP)  \
# 0                        NaN                                  NaN
# 1                        NaN                                  NaN
# 2                        NaN                                  NaN
# 3                        NaN                                  NaN
# 4                        NaN                                  NaN
# ...                      ...                                  ...
# 4984               34.968710                             0.230335
# 4985                     NaN                                  NaN
# 4986                     NaN                                  NaN
# 4987                     NaN                             0.481543
# 4988               22.451986                             0.342305
#
#       Exports of goods and services (% of GDP)  GDP growth (annual %)  \
# 0                                          NaN                    NaN
# ...

# %%
#remove rows without a tourism number
thenData = nextData[nextData['International tourism, number of arrivals'].notna()]
thenData
# Out:
#       Broad money (% of GDP)  CO2 emissions (kg per PPP $ of GDP)  \
# 10                       NaN                                  NaN
# 11                       NaN                                  NaN
# 12                       NaN                                  NaN
# 13                       NaN                                  NaN
# 14                       NaN                                  NaN
# ...                      ...                                  ...
# 4983               31.909760                             0.248930
# 4984               34.968710                             0.230335
# 4985                     NaN                                  NaN
# 4987                     NaN                             0.481543
# 4988               22.451986                             0.342305
#
#       Exports of goods and services (% of GDP)  GDP growth (annual %)  \
# 10                                   99.600000              -0.408163
# ...

# %%
 #counting missing value percentage for each column
percent_missing = thenData.isna().sum()/ len(thenData) *100
missing_value_df = pd.DataFrame({'percent_missing': percent_missing})
missing_value_df = missing_value_df.sort_values(by=['percent_missing'], ascending=False)
missing_value_df
# Out:
#                                                     percent_missing
# Broad money (% of GDP)                                    20.094723
# CO2 emissions (kg per PPP $ of GDP)                       14.208390
# Foreign direct investment, net outflows (% of GDP)        13.802436
# GDP per person employed (constant 2017 PPP $)             11.998196
# Net trade in goods (BoP, current US$)                     11.862878
# Exports of goods and services (% of GDP)                   9.630131
# Imports of goods and services (% of GDP)                   9.630131
# Trade (% of GDP)                                           9.630131
# Services, value added (% of GDP)                           8.096527
# Foreign direct investment, net inflows (% of GDP)          4.691024
# Merchandise trade (% of GDP)                               2.886784
# GDP per capita growth (annual %)                           1.353180
# GDP growth (annual %)                                      1.330627
# ...

# %% [markdown]
# ## Replaced NaN values with 0s

# %%
#going to fill nas with 0s
zeroData = thenData.fillna(0)
zeroData
# Out:
#       Broad money (% of GDP)  CO2 emissions (kg per PPP $ of GDP)  \
# 10                  0.000000                             0.000000
# 11                  0.000000                             0.000000
# 12                  0.000000                             0.000000
# 13                  0.000000                             0.000000
# 14                  0.000000                             0.000000
# ...                      ...                                  ...
# 4983               31.909760                             0.248930
# 4984               34.968710                             0.230335
# 4985                0.000000                             0.000000
# 4987                0.000000                             0.481543
# 4988               22.451986                             0.342305
#
#       Exports of goods and services (% of GDP)  GDP growth (annual %)  \
# 10                                   99.600000              -0.408163
# ...

# %% [markdown]
# ## Model creation

# %% [markdown]
# multivariate regression

# %%
#BoxPlot Feature Set Comparison
fig = plt.figure(figsize=(15,5))
fig.suptitle('Feature Set Comparison')
ax = fig.add_subplot(111)
sns.boxplot(data=zeroData)
plt.show()

# %%
#Correlation Columns with Output
cor = zeroData.corr()
cor_target = abs(cor['International tourism, number of arrivals'])

#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.8]
relevant_features.sort_values(ascending=False)
# Out:
# International tourism, number of arrivals    1.0
# Name: International tourism, number of arrivals, dtype: float64

# %%
#Find Independent Column Correlations
def correlation(dataset,threshold):
    col_corr= [] # List of correlated columns
    corr_matrix=dataset.corr() #finding correlation between columns
    for i in range (len(corr_matrix.columns)): #Number of columns
        for j in range (i):
            if abs(corr_matrix.iloc[i,j])>threshold: #checking correlation between columns
                colName=(corr_matrix.columns[i], corr_matrix.columns[j]) #getting correlated columns
                col_corr.append(colName) #adding correlated column name
    return col_corr #returning set of column names
col=correlation(zeroData,0.8)
print('Correlated columns @ 0.8:', col)
# Out:
# Correlated columns @ 0.8: [('GDP per capita growth (annual %)', 'GDP growth (annual %)'), ('Imports of goods and services (% of GDP)', 'Exports of goods and services (% of GDP)'), ('Trade (% of GDP)', 'Exports of goods and services (% of GDP)'), ('Trade (% of GDP)', 'Imports of goods and services (% of GDP)')]

# %%
#Create Q-Q Plot
from statsmodels.graphics.gofplots import qqplot
import pylab
qqplot(zeroData['International tourism, number of arrivals'],line='s')
pylab.show()

# %% [markdown]
# The QQ chart shows that this is not a normal distribution, polynomial regression might be better

# %%
#Normality test - Shapiro-Wilk Test

#   p <= alpha(0.05): reject H0, not normal.
#   p > alpha(0.05): fail to reject H0, normal.

from scipy.stats import shapiro
stat, p = shapiro(zeroData['International tourism, number of arrivals'])
print('Statistics=%.3f, p=%.3f' % (stat, p))
# interpret
alpha = 0.05
if p > alpha:
    print('Sample looks Gaussian (fail to reject H0)')
else:
    print('Sample does not look Gaussian (reject H0)')
# Out:
# Statistics=0.386, p=0.000
# Sample does not look Gaussian (reject H0)

# %% [markdown]
# ## ACTUAL MODEL CREATION

# %%
#Create Standard Model

#Define x and y variable
x = zeroData.drop('International tourism, number of arrivals',axis=1).to_numpy()
y = zeroData['International tourism, number of arrivals'].to_numpy()

#Create Train and Test Datasets
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

#Scale the Data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train2 = sc.fit_transform(x_train)
x_test2 = sc.transform(x_test)

#Model
from sklearn.linear_model import LinearRegression

# %%
#Create Model

from sklearn import metrics

for name,method in [('Linear regression', LinearRegression())]: 
    method.fit(x_train2,y_train)
    predict = method.predict(x_test2)

print('\nOriginal Model')
print('\nMethod: {}'.format(name))   

#Coefficents
print('\nIntercept: {:.2f}'.format(float(method.intercept_)))
coeff_table=pd.DataFrame(np.transpose(method.coef_),zeroData.drop('International tourism, number of arrivals',axis=1).columns,columns=['Coefficients'])
print(coeff_table)
    
#R2,MAE,MSE and RMSE
print('\nR2: {:.2f}'.format(metrics.r2_score(y_test,predict)))
adjusted_r_squared = 1-(1-metrics.r2_score(y_test,predict))*(len(y)-1)/(len(y)-x.shape[1]-1)
print('Adj_R2: {:0.2f}'.format(adjusted_r_squared))
print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(y_test, predict)))  
print('Mean Squared Error: {:.2f}'.format(metrics.mean_squared_error(y_test, predict)))  
print('Root Mean Squared Error: {:.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, predict))))
# Out:
# Original Model
#
# Method: Linear regression
#
# Intercept: 8281199.96
#                                                     Coefficients
# Broad money (% of GDP)                              2.065909e+06
# CO2 emissions (kg per PPP $ of GDP)                 8.264646e+05
# Exports of goods and services (% of GDP)            6.803247e+14
# GDP growth (annual %)                              -9.612838e+06
# Foreign direct investment, net inflows (% of GDP)  -1.062560e+06
# Foreign direct investment, net outflows (% of GDP)  2.850820e+05
# GDP per capita growth (annual %)                    1.028319e+07
# Imports of goods and services (% of GDP)            6.470432e+14
# Merchandise trade (% of GDP)                        3.208575e+03
# Inflation, GDP deflator (annual %)                 -1.580671e+05
# Trade (% of GDP)                                   -1.282993e+15
# Services, value added (% of GDP)                    9.296560e+05
# ...

# %%
#Scatterplots - MPG vs. Independent Variables

plt.figure(figsize = (15, 20))

cnt = 1
for col in zeroData.columns:
    if (col == 'International tourism, number of arrivals'):
        continue
    
    plt.subplot(5, 2, cnt)
    lmgraph = sns.regplot(x = zeroData[col], y = zeroData['International tourism, number of arrivals'])
    lmgraph.set_xlabel(col)
    lmgraph.set_ylabel('International tourism, number of arrivals')
    cnt += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-90212ad79075> in <module>
#       8         continue
#       9
# ---> 10     plt.subplot(5, 2, cnt)
#      11     lmgraph = sns.regplot(x = zeroData[col], y = zeroData['International tourism, number of arrivals'])
#      12     lmgraph.set_xlabel(col)
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1140
#    1141     fig = gcf()
# -> 1142     ax = fig.add_subplot(*args, **kwargs)
#    1143     bbox = ax.bbox
#    1144     axes_to_delete = []
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in add_subplot(self, *args, **kwargs)
#    1400                     # more similar to add_axes.
#    1401                     self._axstack.remove(ax)
# -> 1402             ax = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1403
# ...

# %%
# Construct some pipelines 
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

#Create Pipeline

pipeline =[]

pipe_lm = Pipeline([('scl', StandardScaler()),
                    ('clf', LinearRegression())])
pipeline.insert(0,pipe_lm)

# Set grid search params 

modelpara =[]

param_gridlm = {'clf__fit_intercept':[True,False],
                'clf__copy_X':[True, False]}
modelpara.insert(0,param_gridlm)

# %%
#Create Learning Curve
from sklearn.model_selection import learning_curve

def plot_learning_curves(model):
    train_sizes, train_scores, test_scores = learning_curve(estimator=model,
                                                            X=x_train, 
                                                            y=y_train,
                                                            train_sizes=np.linspace(.1,1,10),
                                                            scoring = 'neg_mean_squared_error',
                                                            cv=10,random_state=100)
    
    train_mean = np.sqrt(np.mean(-train_scores, axis=1))
    train_std = np.sqrt(np.std(-train_scores, axis=1))
    test_mean = np.sqrt(np.mean(-test_scores, axis=1))
    test_std = np.sqrt(np.std(-test_scores, axis=1))
    
    plt.plot(train_sizes, train_mean,color='blue', marker='o', 
             markersize=5, label='training accuracy')
    plt.fill_between(train_sizes, train_mean + train_std, train_mean - train_std,
                     alpha=0.15, color='blue')

    plt.plot(train_sizes, test_mean, color='green', linestyle='--', marker='s', markersize=5,
             label='validation accuracy')
    plt.fill_between(train_sizes, test_mean + test_std, test_mean - test_std,
                     alpha=0.15, color='green')
    plt.grid()
    plt.xlabel('Number of training samples')
    plt.ylabel('RMSE')
    plt.legend(loc='best')
    plt.ylim([-1,20])
    plt.show()

# %%
#Plot Learning Curve
lm=LinearRegression()
print('LM Learning Curve')
plot_learning_curves(pipe_lm)
# Out:
# LM Learning Curve

# %%
#Model Analysis
from sklearn.model_selection import RepeatedKFold
from sklearn.model_selection import cross_val_score

models=[]
models.append(('Linear Regression',pipe_lm))

#Model Evaluation
results =[]
names=[]
scoring ='neg_mean_squared_error'
print('Model Evaluation - RMSE')
for name, model in models:
    rkf=RepeatedKFold(n_splits=10, n_repeats=5, random_state=100)
    cv_results = cross_val_score(model,x,y,cv=rkf,scoring=scoring)
    results.append(np.sqrt(-cv_results))
    names.append(name)
    print('{} {:.2f}'.format(name,np.sqrt(-cv_results.mean())))
print('\n')

fig = plt.figure(figsize=(5,5))
fig.suptitle('Boxplot View')
ax = fig.add_subplot(111)
sns.boxplot(data=results)
ax.set_xticklabels(names)
plt.ylabel('RMSE')
plt.xlabel('Model')
plt.show()
# Out:
# Model Evaluation - RMSE
# Linear Regression 20496367.47

# %%
#Define Gridsearch Function

from sklearn.model_selection import GridSearchCV

def Gridsearch_cv(model, params):
    
    #Cross-validation Function
    cv2=RepeatedKFold(n_splits=10, n_repeats=5, random_state=100)
        
    #GridSearch CV
    gs_clf = GridSearchCV(model, params, cv=cv2,scoring='neg_mean_squared_error')
    gs_clf = gs_clf.fit(x_train, y_train)
    model = gs_clf.best_estimator_
    
    # Use best model and test data for final evaluation
    y_pred = model.predict(x_test)

    #Identify Best Parameters to Optimize the Model
    bestpara=str(gs_clf.best_params_)
   
    #Output Heading
    print('\nOptimized Model')
    print('\nModel Name:',str(pipeline.named_steps['clf']))
        
    #Output Validation Statistics
    print('\nBest Parameters:',bestpara)
    
    #Test data accuracy of model with best params    
    print('\nIntercept: {:.2f}'.format(float(gs_clf.best_estimator_.named_steps['clf'].intercept_)))
    print('\nModel coefficients: ')   
    for name, score in zip(list(zeroData.drop('International tourism, number of arrivals',axis=1)),
                           gs_clf.best_estimator_.named_steps['clf'].coef_):
         print(name, round(score,2)) 
    
    #Print R2
    print('\nR2: {:0.2f}'.format(metrics.r2_score(y_test,y_pred)))
    adjusted_r_squared2 = 1-(1-metrics.r2_score(y_test,y_pred))*(len(y)-1)/(len(y)-x.shape[1]-1)
    print('Adj_R2: {:0.2f}'.format(adjusted_r_squared2))

    #Print MSE and RMSE
    print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(y_test, y_pred)))  
    print('Mean Squared Error: {:.2f}'.format(metrics.mean_squared_error(y_test, y_pred)))  
    print('Root Mean Squared Error: {:.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, y_pred))))

# %%
#Run Models
for pipeline, modelpara in zip(pipeline,modelpara):
    Gridsearch_cv(pipeline,modelpara)
# Out:
# Optimized Model
#
# Model Name: LinearRegression()
#
# Best Parameters: {'clf__copy_X': True, 'clf__fit_intercept': True}
#
# Intercept: 8281199.96
#
# Model coefficients:
# Broad money (% of GDP) 2065909.18
# CO2 emissions (kg per PPP $ of GDP) 826464.65
# Exports of goods and services (% of GDP) 680324724601488.2
# GDP growth (annual %) -9612837.51
# Foreign direct investment, net inflows (% of GDP) -1062560.19
# Foreign direct investment, net outflows (% of GDP) 285082.02
# GDP per capita growth (annual %) 10283194.08
# Imports of goods and services (% of GDP) 647043245062714.8
# Merchandise trade (% of GDP) 3208.58
# Inflation, GDP deflator (annual %) -158067.07
# Trade (% of GDP) -1282993138094050.2
# Services, value added (% of GDP) 929656.01
# GDP per person employed (constant 2017 PPP $) 6652096.93
# Net trade in goods (BoP, current US$) -5338564.47
#
# R2: 0.18
# Adj_R2: 0.18
# Mean Absolute Error: 10256488.91
# Mean Squared Error: 466004413230199.19
# ...

# %%
#If Not normal you can use Yeo-Johnson Transformation

#Load Dataset
dataset_trf=zeroData

#Define x and y variable
x_trf=dataset_trf.drop('International tourism, number of arrivals',axis=1).to_numpy()
y_trf=dataset_trf['International tourism, number of arrivals'].to_numpy()

#Create Train and Test
from sklearn.model_selection import train_test_split
x_train_trf,x_test_trf,y_train_trf,y_test_trf=train_test_split(x_trf,y_trf,test_size=0.2,random_state=100)

#Converting variables to 2D
y_train_trf = y_train_trf.reshape(-1,1)
y_test_trf = y_test_trf.reshape(-1,1)

#Scale Independent Variables
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_trf = sc.fit_transform(x_train_trf)
x_test_trf = sc.transform(x_test_trf)

#Tranform Dependent Variable
from sklearn.preprocessing import power_transform
transf_ytrain=power_transform(y_train_trf,method='yeo-johnson')
transf_ytest=power_transform(y_test_trf,method='yeo-johnson')

# %%
#Create Tranformed Model
for name,method2 in [('Linear regression', LinearRegression())]: 
    method2.fit(x_train_trf,transf_ytrain)
    predict = method2.predict(x_test_trf)

print('\nTransformed Model - Yeo-Johnson')
print('\nMethod: {}'.format(name)) 

#Coefficents
print('\nIntercept: {:0.2f}'.format(float(method2.intercept_)))
print('\n')
coeff_table2=pd.DataFrame(np.transpose(method2.coef_),dataset_trf.drop('International tourism, number of arrivals',axis=1).columns,
                          columns=['Model Coefficients'])
print(coeff_table)
    
#R2 and RMSE
print('\nR2: {:0.2f}'.format(metrics.r2_score(transf_ytest,predict)))
adjusted_r_squared2 = 1-(1-metrics.r2_score(transf_ytest,predict))*(len(y_trf)-1)/(len(y_trf)-x_trf.shape[1]-1)
print('Adj_R2: {:0.2f}'.format(adjusted_r_squared2))
print('Root Mean Squared Error: {:0.2f}'.format(np.exp(np.sqrt(metrics.mean_squared_error(transf_ytest, predict)))))
# Out:
# Transformed Model - Yeo-Johnson
#
# Method: Linear regression
#
# Intercept: -0.00
#
#
#                                                     Coefficients
# Broad money (% of GDP)                              2.065909e+06
# CO2 emissions (kg per PPP $ of GDP)                 8.264646e+05
# Exports of goods and services (% of GDP)            6.803247e+14
# GDP growth (annual %)                              -9.612838e+06
# Foreign direct investment, net inflows (% of GDP)  -1.062560e+06
# Foreign direct investment, net outflows (% of GDP)  2.850820e+05
# GDP per capita growth (annual %)                    1.028319e+07
# Imports of goods and services (% of GDP)            6.470432e+14
# Merchandise trade (% of GDP)                        3.208575e+03
# Inflation, GDP deflator (annual %)                 -1.580671e+05
# Trade (% of GDP)                                   -1.282993e+15
# Services, value added (% of GDP)                    9.296560e+05
# ...

# %% [markdown]
# ## possible poylnomyial regression below this

# %%
#Define x and y variable
x = zeroData.drop('International tourism, number of arrivals',axis=1).to_numpy()
y = zeroData['International tourism, number of arrivals'].to_numpy()

#Create Train and Test Dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

#Scale the Data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train2 = sc.fit_transform(x_train)
x_test2 = sc.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

for name,method in [('Linear regression', LinearRegression())]: 
    method.fit(x_train2,y_train)
    predict = method.predict(x_test2)

print('\nOriginal Model')
print('\nMethod: {}'.format(name))   

#Coefficents
print('\nIntercept: {:.2f}'.format(float(method.intercept_)))
coeff_table=pd.DataFrame(np.transpose(method.coef_),zeroData.drop('International tourism, number of arrivals',axis=1).columns,columns=['Coefficients'])
print(coeff_table)
    
#R2,MAE,MSE and RMSE
print('\nR2: {:.2f}'.format(metrics.r2_score(y_test,predict)))
adjusted_r_squared = 1-(1-metrics.r2_score(y_test,predict))*(len(y)-1)/(len(y)-x.shape[1]-1)
print('Adj_R2: {:0.2f}'.format(adjusted_r_squared))
print('Mean Absolute Error: {:.2f}'.format(metrics.mean_absolute_error(y_test, predict)))  
print('Mean Squared Error: {:.2f}'.format(metrics.mean_squared_error(y_test, predict)))  
print('Root Mean Squared Error: {:.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, predict))))
# Out:
# Original Model
#
# Method: Linear regression
#
# Intercept: 8281199.96
#                                                     Coefficients
# Broad money (% of GDP)                              2.065909e+06
# CO2 emissions (kg per PPP $ of GDP)                 8.264646e+05
# Exports of goods and services (% of GDP)            6.803247e+14
# GDP growth (annual %)                              -9.612838e+06
# Foreign direct investment, net inflows (% of GDP)  -1.062560e+06
# Foreign direct investment, net outflows (% of GDP)  2.850820e+05
# GDP per capita growth (annual %)                    1.028319e+07
# Imports of goods and services (% of GDP)            6.470432e+14
# Merchandise trade (% of GDP)                        3.208575e+03
# Inflation, GDP deflator (annual %)                 -1.580671e+05
# Trade (% of GDP)                                   -1.282993e+15
# Services, value added (% of GDP)                    9.296560e+05
# ...

# %%
#Search for an optimal Polynominal
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import PolynomialFeatures

poly_range = range(1, 5)
poly_scores = []

for poly in poly_range:
    poly_features = PolynomialFeatures(degree=poly)
    X_train_poly = poly_features.fit_transform(x_train2)
    poly_model = LinearRegression()
    #obtain cross_val_score for Polynomial Regression Degree
    poly_score = cross_val_score(poly_model, X_train_poly, y_train, cv=10, scoring='neg_mean_squared_error')
    #append mean of scores for Polynominal Regression Degree
    poly_scores.append(poly_score.mean())
    
BestPoly = [1 - x for x in poly_scores]
best_poly = poly_range[BestPoly.index(min(BestPoly))]
print('Best Degree - Poly:  ',best_poly)
# Out:
# Best Degree - Poly:   2

# %%
# Polynomial Regression Model
from sklearn.pipeline import make_pipeline
pd.set_option('display.max_rows', 200)
poly = PolynomialFeatures(best_poly)
linr = LinearRegression()
model = make_pipeline(poly, linr)
model.fit(x_train2, y_train)
coeff_table2=pd.DataFrame(np.transpose(model.steps[1][1].coef_),
                          model.steps[0][1].get_feature_names(zeroData.columns.drop(['International tourism, number of arrivals'])),
                          columns=['Model Coefficients'])

#predicting on test data-set    X_train_poly = poly_features.fit_transform(x_train2)
X_train_poly = poly.fit_transform(x_train2)
y_test_predict = model.predict(x_test2)

#Polynominal Regression Model
print('\nPolynominal Regression Model')
print('\nPolynomial Degree: {}'.format(best_poly))

print('\nIntercept: {:.2f}'.format(model.steps[1][1].intercept_))

coeff_table2=pd.DataFrame(np.transpose(model.steps[1][1].coef_),
                          model.steps[0][1].get_feature_names(zeroData.columns.drop(['International tourism, number of arrivals'])),
                          columns=['Model Coefficients'])
print('\n',coeff_table2.drop('1',axis=0))
print('\nR2: {:.2f}'.format(metrics.r2_score(y_test,y_test_predict)))
adjusted_r_squared2 = 1-(1-metrics.r2_score(y_test,y_test_predict))*(len(y)-1)/(len(y)-x.shape[1]-1)
print('Adj_R2: {:0.2f}'.format(adjusted_r_squared2))
print('\nMAE: {:0.2f}'.format(metrics.mean_absolute_error(y_test, y_test_predict)))
print('Mean Squared Error: {:0.2f}'.format(metrics.mean_squared_error(y_test, y_test_predict)))
print('Root Mean Squared Error: {:0.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, y_test_predict))))
# Out:
# Polynominal Regression Model
#
# Polynomial Degree: 2
#
# Intercept: 174358127.61
#
#                                                      Model Coefficients
# Broad money (% of GDP)                                   -1.473624e+06
# CO2 emissions (kg per PPP $ of GDP)                      -9.843770e+03
# Exports of goods and services (% of GDP)                  1.589007e+14
# GDP growth (annual %)                                    -4.570194e+06
# Foreign direct investment, net inflows (% of GDP)        -3.726138e+06
# Foreign direct investment, net outflows (% of GDP)        3.191731e+06
# GDP per capita growth (annual %)                          4.708615e+06
# Imports of goods and services (% of GDP)                  1.511272e+14
# Merchandise trade (% of GDP)                              4.631492e+05
# Inflation, GDP deflator (annual %)                       -2.189035e+06
# Trade (% of GDP)                                         -2.996635e+14
# ...

# %%
#First you need to install pygam using pip install pygam at the Anaconda prompt

#GAM Models
from pygam import LinearGAM

#Fit a model using Gridsearch default parameters
gam = LinearGAM(n_splines=5).gridsearch(x_train2,y_train)

#Create Prediction

gam_pred = gam.predict(x_test2)

#Calculate MAE, MSE and RMSE
print('\nR2: {:.2f}'.format(metrics.r2_score(y_test,gam_pred)))
adjusted_r_squared2 = 1-(1-metrics.r2_score(y_test,gam_pred))*(len(y)-1)/(len(y)-x.shape[1]-1)
print('Adj_R2: {:0.2f}'.format(adjusted_r_squared2))
print('\nMean Absolute Error: {:0.2f}'.format(metrics.mean_absolute_error(y_test, gam_pred)))  
print('MSE: {:0.2f}'.format(metrics.mean_squared_error(y_test, gam_pred)))  
print('RSME: {:0.2f}'.format(np.sqrt(metrics.mean_squared_error(y_test, gam_pred))))
# Out:
# 100% (11 of 11) |########################| Elapsed Time: 0:00:02 Time:  0:00:02
# R2: 0.34
# Adj_R2: 0.34
#
# Mean Absolute Error: 8944456.27
# MSE: 377844873383179.81
# RSME: 19438232.26
